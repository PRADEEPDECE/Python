# %% [markdown]
# ___
#
# <img src='../Beat logo.png'/></a>
# ___
# <center><em>Content Copyright by Beat</em></center>

# %% [markdown]
# # Opening and Reading Files
#
# So far we've discussed how to open files manually, one by one. Let's explore how we can open files programatically.

# %% [markdown]
# _____

# %% [markdown]
# ### Review: Understanding File Paths

# %%
#pwd
import os
os.getcwd()
# Out:
# 'C:\\Users\\prade\\3D Objects\\Complete-Python-3-Eacademy Bootcamp-master\\Complete-Python-3-Eacademy Bootcamp-master\\12-Advanced Python Modules'

# %% [markdown]
# ### Create Practice File
#
# We will begin by creating a practice text file that we will be using for demonstration.

# %%
f = open('practice.txt','w+')

# %%
f.write('test')
f.close()

# %% [markdown]
# ### Getting Directories
#
# Python has a built-in [os module](https://docs.python.org/3/library/os.html) that allows us to use operating system dependent functionality.
#
# You can get the current directory:

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\prade\\3D Objects\\Complete-Python-3-Eacademy Bootcamp-master\\Complete-Python-3-Eacademy Bootcamp-master\\12-Advanced Python Modules'

# %% [markdown]
# ### Listing Files in a Directory
#
# You can also use the os module to list directories.

# %%
# In your current directory
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '02-Datetime-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'comp_file1.zip',
#  'Example_Top_Level',
#  'new_file.txt',
#  'new_file2.txt',
#  'os.getcwd()',
#  'practice.txt',
#  'practice1.txt']

# %%
# In any directory you pass
os.listdir("C:\\Users")
# Out:
# ['All Users',
#  'Default',
#  'Default User',
#  'DefaultAppPool.LOG1',
#  'DefaultAppPool.LOG2',
#  'desktop.ini',
#  'prade',
#  'Public']

# %% [markdown]
# ### Moving Files
#
# You can use the built-in **shutil** module to to move files to different locations. Keep in mind, there are permission restrictions, for example if you are logged in a User A, you won't be able to make changes to the top level Users folder without the proper permissions, [more info](https://stackoverflow.com/questions/23253439/shutil-movescr-dst-gets-me-ioerror-errno-13-permission-denied-and-3-more-e)

# %%
import shutil
dir(shutil)
# Out:
# ['COPY_BUFSIZE',
#  'Error',
#  'ExecError',
#  'ReadError',
#  'RegistryError',
#  'SameFileError',
#  'SpecialFileError',
#  '_ARCHIVE_FORMATS',
#  '_BZ2_SUPPORTED',
#  '_GiveupOnFastCopy',
#  '_HAS_FCOPYFILE',
#  '_LZMA_SUPPORTED',
#  '_UNPACK_FORMATS',
#  '_USE_CP_SENDFILE',
#  '_WINDOWS',
#  '_WIN_DEFAULT_PATHEXT',
#  '_ZLIB_SUPPORTED',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_access_check',
#  '_basename',
#  '_check_unpack_options',
#  '_copyfileobj_readinto',
#  '_copytree',
#  '_copyxattr',
#  '_destinsrc',
#  '_ensure_directory',
#  '_fastcopy_fcopyfile',
#  '_fastcopy_sendfile',
#  '_find_unpack_format',
#  '_get_gid',
#  '_get_uid',
#  '_is_immutable',
#  '_islink',
#  '_make_tarball',
#  '_make_zipfile',
#  '_ntuple_diskusage',
#  '_rmtree_isdir',
#  '_rmtree_islink',
#  '_rmtree_safe_fd',
#  '_rmtree_unsafe',
#  '_samefile',
#  '_stat',
#  '_unpack_tarfile',
#  '_unpack_zipfile',
#  '_use_fd_functions',
#  'chown',
#  'collections',
#  'copy',
#  'copy2',
#  'copyfile',
#  'copyfileobj',
#  'copymode',
#  'copystat',
#  'copytree',
#  'disk_usage',
#  'errno',
#  'fnmatch',
#  'get_archive_formats',
#  'get_terminal_size',
#  'get_unpack_formats',
#  'ignore_patterns',
#  'make_archive',
#  'move',
#  'nt',
#  'os',
#  'posix',
#  'register_archive_format',
#  'register_unpack_format',
#  'rmtree',
#  'stat',
#  'sys',
#  'unpack_archive',
#  'unregister_archive_format',
#  'unregister_unpack_format',
#  'which']

# %%
shutil.move('practice.txt','c:\\users\\prade')
# Out:
# 'c:\\users\\prade\\practice.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '02-Datetime-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'comp_file1.zip',
#  'Example_Top_Level',
#  'new_file.txt',
#  'new_file2.txt',
#  'os.getcwd()',
#  'practice1.txt']

# %%
shutil.move('C:\\Users\\prade\practice.txt',os.getcwd())
# Out:
# 'C:\\Users\\prade\\3D Objects\\Complete-Python-3-Eacademy Bootcamp-master\\Complete-Python-3-Eacademy Bootcamp-master\\12-Advanced Python Modules\\practice.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '02-Datetime-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'comp_file1.zip',
#  'Example_Top_Level',
#  'new_file.txt',
#  'new_file2.txt',
#  'os.getcwd()',
#  'practice.txt',
#  'practice1.txt']

# %% [markdown]
# ### Deleting Files
# ____
# **NOTE: The os module provides 3 methods for deleting files:**
# * os.unlink(path) which deletes a file at the path your provide
# * os.rmdir(path) which deletes a folder (folder must be empty) at the path your provide
# * shutil.rmtree(path) this is the most dangerous, as it will remove all files and folders contained in the path.
# **All of these methods can not be reversed! Which means if you make a mistake you won't be able to recover the file. Instead we will use the send2trash module. A safer alternative that sends deleted files to the trash bin instead of permanent removal.**
# ___
#
# Install the send2trash module with:
#
#     pip install send2trash
#
# at your command line.

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '02-Datetime-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'comp_file1.zip',
#  'Example_Top_Level',
#  'new_file.txt',
#  'new_file2.txt',
#  'os.getcwd()',
#  'practice.txt',
#  'practice1.txt']

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '02-Datetime-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'comp_file1.zip',
#  'Example_Top_Level',
#  'new_file.txt',
#  'new_file2.txt',
#  'os.getcwd()',
#  'practice1.txt']

# %% [markdown]
# ### Walking through a directory
#
# Often you will just need to "walk" through a directory, that is visit every file or folder and check to see if a file is in the directory, and then perhaps do something with that file. Usually recursively walking through every file and folder in a directory would be quite tricky to program, but luckily the os module has a direct method call for this called os.walk(). Let's explore how it works.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\prade\\3D Objects\\Complete-Python-3-Eacademy Bootcamp-master\\Complete-Python-3-Eacademy Bootcamp-master\\12-Advanced Python Modules'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '02-Datetime-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'comp_file.zip',
#  'comp_file1.zip',
#  'Example_Top_Level',
#  'new_file.txt',
#  'new_file2.txt',
#  'os.getcwd()',
#  'practice1.txt']

# %%
for folder , sub_folders , files in os.walk("Example_Top_Level"):
    
    print("Currently looking at folder: "+ folder)
    print('\n')
    print("THE SUBFOLDERS ARE: ")
    for sub_fold in sub_folders:
        print("\t Subfolder: "+sub_fold )
    
    print('\n')
    
    print("THE FILES ARE: ")
    for f in files:
        print("\t File: "+f)
    print('\n')
    
    # Now look at subfolders
# Out:
# Currently looking at folder: Example_Top_Level
#
#
# THE SUBFOLDERS ARE:
# 	 Subfolder: Mid-Example-One
#
#
# THE FILES ARE:
# 	 File: Mid-Example.txt
#
#
# Currently looking at folder: Example_Top_Level\Mid-Example-One
#
#
# THE SUBFOLDERS ARE:
# 	 Subfolder: Bottom-Level-One
# 	 Subfolder: Bottom-Level-Two
#
#
# THE FILES ARE:
# 	 File: Mid-Level-Doc.txt
#
#
# Currently looking at folder: Example_Top_Level\Mid-Example-One\Bottom-Level-One
#
#
# THE SUBFOLDERS ARE:
#
#
# THE FILES ARE:
# 	 File: One_Text.txt
#
#
# Currently looking at folder: Example_Top_Level\Mid-Example-One\Bottom-Level-Two
#
#
# THE SUBFOLDERS ARE:
#
#
# THE FILES ARE:
# 	 File: Bottom-Text-Two.txt

# %%
list(os.walk("Example_Top_Level"))
list(os.walk("C:\\Users\\prade\\OneDrive\\Documents\\R\\win-library\\4.1\\g.data"))
# Out:
# [('C:\\Users\\prade\\OneDrive\\Documents\\R\\win-library\\4.1\\g.data',
#   ['doc', 'help', 'html', 'Meta', 'R'],
#   ['DESCRIPTION', 'INDEX', 'MD5', 'NAMESPACE']),
#  ('C:\\Users\\prade\\OneDrive\\Documents\\R\\win-library\\4.1\\g.data\\doc',
#   [],
#   ['g.data.pdf', 'g.data.R', 'g.data.Rnw', 'index.html']),
#  ('C:\\Users\\prade\\OneDrive\\Documents\\R\\win-library\\4.1\\g.data\\help',
#   [],
#   ['aliases.rds', 'AnIndex', 'g.data.rdb', 'g.data.rdx', 'paths.rds']),
#  ('C:\\Users\\prade\\OneDrive\\Documents\\R\\win-library\\4.1\\g.data\\html',
#   [],
#   ['00Index.html', 'R.css']),
#  ('C:\\Users\\prade\\OneDrive\\Documents\\R\\win-library\\4.1\\g.data\\Meta',
#   [],
#   ['features.rds',
#    'hsearch.rds',
#    'links.rds',
#    'nsInfo.rds',
#    'package.rds',
#    'Rd.rds',
#    'vignette.rds']),
#  ('C:\\Users\\prade\\OneDrive\\Documents\\R\\win-library\\4.1\\g.data\\R',
#   [],
#   ['g.data', 'g.data.rdb', 'g.data.rdx'])]

# %%
list(os.walk("c:\\"))
# Out:
# [('c:\\',
#   ['$Recycle.Bin',
#    '$WINDOWS.~BT',
#    '$Windows.~WS',
#    '$WinREAgent',
#    '.cleverfiles',
#    'ADE',
#    'apache',
#    'apache-maven-3.9.4',
#    'app',
#    'AtomicRedTeam',
#    'attackworkbench',
#    'Boot',
#    'Documents and Settings',
#    'Downloaded Web Sites',
#    'Drivers',
#    'Electricity_Billing_System-master',
#    'gitrepository',
#    'inetpub',
#    'Intel',
#    'ja-netfilter-all',
#    'My Web Sites',
#    'N-Stalker',
#    'OneDriveTemp',
#    'PerfLogs',
#    'PortQryUI',
#    'Program Files',
#    'Program Files (x86)',
#    'ProgramData',
#    'Python312',
#    'Recovered',
#    'Recovery',
#    'Ruby32-x64',
#    'System Volume Information',
#    'temp',
#    'tenorshare',
#    'tomcat',
#    'TURBOC3',
#    'Users',
#    'wamp64',
#    'Windows'],
#   ['appverifUI.dll',
#    'bootmgr',
#    'demo.txt',
#    'DumpStack.log.tmp',
#    'Electricity_Billing_System-master.zip',
#    'hashes.txt',
#    'hiberfil.sys',
#    'pagefile.sys',
#    'swapfile.sys',
#    'users.txt',
#    'vfcompat.dll']),
#  ('c:\\$Recycle.Bin',
#   ['S-1-5-18', 'S-1-5-21-3846033030-166380806-3488247521-1001'],
#   []),
#  ('c:\\$Recycle.Bin\\S-1-5-21-3846033030-166380806-3488247521-1001',
#   [],
#   ['$I9OQQ1B.txt',
#    '$R9OQQ1B.txt',
#    '.\udc6d\udc73\udc79\udc7300040000001bb5770b66cd5960c4b752',
#    '.\udc6d\udc73\udc79\udc7300050000001bb4fa6877e72364ed0ea3',
#    'desktop.ini']),
#  ('c:\\$WINDOWS.~BT', ['Sources'], []),
#  ('c:\\$WINDOWS.~BT\\Sources', ['Panther'], []),
#  ('c:\\$WINDOWS.~BT\\Sources\\Panther', [], []),
#  ('c:\\$Windows.~WS', ['Sources'], []),
#  ('c:\\$Windows.~WS\\Sources', ['Panther'], []),
#  ('c:\\$Windows.~WS\\Sources\\Panther',
#   [],
#   ['diagerr.xml',
#    'diagwrn.xml',
#    'Eula.rtf',
#    'setupact.log',
#    'setuperr.log',
#    'windlp.state-old.xml',
#    'windlp.state.xml']),
#  ('c:\\$WinREAgent',
#   ['Backup', 'Rollback', 'Scratch'],
#   ['Rollback.xml', 'RollbackInfo.ini']),
#  ('c:\\$WinREAgent\\Backup',
#   [],
#   ['boot.sdi', 'location.txt', 'ReAgent.xml', 'Winre.wim']),
#  ('c:\\$WinREAgent\\Rollback', [], []),
#  ('c:\\$WinREAgent\\Scratch', ['WimTempPath'], ['update.wim']),
#  ('c:\\$WinREAgent\\Scratch\\WimTempPath', [], []),
#  ('c:\\.cleverfiles',
#   [],
#   ['dead.db', 'dead.db.jrn', 'live.db', 'live.db.jrn', 'pref.plist']),
#  ('c:\\ADE', ['AIME_V'], []),
#  ('c:\\ADE\\AIME_V', ['ORACLE'], []),
#  ('c:\\ADE\\AIME_V\\ORACLE', ['ADMIN'], []),
#  ('c:\\ADE\\AIME_V\\ORACLE\\ADMIN', ['SEEDDATA', 'XE'], []),
#  ('c:\\ADE\\AIME_V\\ORACLE\\ADMIN\\SEEDDATA', ['DPDUMP'], []),
#  ('c:\\ADE\\AIME_V\\ORACLE\\ADMIN\\SEEDDATA\\DPDUMP',
#   ['1160AC5AAC824BDE894E44B4C2401B3E'],
#   []),
#  ('c:\\ADE\\AIME_V\\ORACLE\\ADMIN\\SEEDDATA\\DPDUMP\\1160AC5AAC824BDE894E44B4C2401B3E',
#   [],
#   ['ORA_DUMMY_FILE.F']),
#  ('c:\\ADE\\AIME_V\\ORACLE\\ADMIN\\XE', ['DPDUMP'], []),
#  ('c:\\ADE\\AIME_V\\ORACLE\\ADMIN\\XE\\DPDUMP',
#   ['56527088DAE24D40B9130A3B353479F6'],
#   []),
#  ('c:\\ADE\\AIME_V\\ORACLE\\ADMIN\\XE\\DPDUMP\\56527088DAE24D40B9130A3B353479F6',
#   [],
#   []),
#  ('c:\\apache', ['apache-tomcat-10.1.8'], []),
#  ('c:\\apache\\apache-tomcat-10.1.8',
#   ['bin', 'conf', 'lib', 'logs', 'temp', 'webapps', 'work'],
#   ['BUILDING.txt',
#    'CONTRIBUTING.md',
#    'LICENSE',
#    'NOTICE',
#    'README.md',
#    'RELEASE-NOTES',
#    'RUNNING.txt']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\bin',
#   [],
#   ['bootstrap.jar',
#    'catalina-tasks.xml',
#    'catalina.bat',
#    'catalina.sh',
#    'ciphers.bat',
#    'ciphers.sh',
#    'commons-daemon-native.tar.gz',
#    'commons-daemon.jar',
#    'configtest.bat',
#    'configtest.sh',
#    'daemon.sh',
#    'digest.bat',
#    'digest.sh',
#    'makebase.bat',
#    'makebase.sh',
#    'migrate.bat',
#    'migrate.sh',
#    'setclasspath.bat',
#    'setclasspath.sh',
#    'shutdown.bat',
#    'shutdown.sh',
#    'startup.bat',
#    'startup.sh',
#    'tomcat-juli.jar',
#    'tomcat-native.tar.gz',
#    'tool-wrapper.bat',
#    'tool-wrapper.sh',
#    'version.bat',
#    'version.sh']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\conf',
#   [],
#   ['catalina.policy',
#    'catalina.properties',
#    'context.xml',
#    'jaspic-providers.xml',
#    'jaspic-providers.xsd',
#    'logging.properties',
#    'server.xml',
#    'tomcat-users.xml',
#    'tomcat-users.xsd',
#    'web.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\lib',
#   [],
#   ['annotations-api.jar',
#    'catalina-ant.jar',
#    'catalina-ha.jar',
#    'catalina-ssi.jar',
#    'catalina-storeconfig.jar',
#    'catalina-tribes.jar',
#    'catalina.jar',
#    'ecj-4.27.jar',
#    'el-api.jar',
#    'jakartaee-migration-1.0.6-shaded.jar',
#    'jasper-el.jar',
#    'jasper.jar',
#    'jaspic-api.jar',
#    'jsp-api.jar',
#    'servlet-api.jar',
#    'tomcat-api.jar',
#    'tomcat-coyote.jar',
#    'tomcat-dbcp.jar',
#    'tomcat-i18n-cs.jar',
#    'tomcat-i18n-de.jar',
#    'tomcat-i18n-es.jar',
#    'tomcat-i18n-fr.jar',
#    'tomcat-i18n-ja.jar',
#    'tomcat-i18n-ko.jar',
#    'tomcat-i18n-pt-BR.jar',
#    'tomcat-i18n-ru.jar',
#    'tomcat-i18n-zh-CN.jar',
#    'tomcat-jdbc.jar',
#    'tomcat-jni.jar',
#    'tomcat-util-scan.jar',
#    'tomcat-util.jar',
#    'tomcat-websocket.jar',
#    'websocket-api.jar',
#    'websocket-client-api.jar']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\logs', [], []),
#  ('c:\\apache\\apache-tomcat-10.1.8\\temp', [], ['safeToDelete.tmp']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps',
#   ['docs', 'examples', 'host-manager', 'manager', 'ROOT'],
#   []),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs',
#   ['annotationapi',
#    'api',
#    'appdev',
#    'architecture',
#    'config',
#    'elapi',
#    'images',
#    'jaspicapi',
#    'jspapi',
#    'META-INF',
#    'servletapi',
#    'tribes',
#    'WEB-INF',
#    'websocketapi'],
#   ['aio.html',
#    'apr.html',
#    'balancer-howto.html',
#    'building.html',
#    'BUILDING.txt',
#    'cdi.html',
#    'cgi-howto.html',
#    'changelog.html',
#    'class-loader-howto.html',
#    'cluster-howto.html',
#    'comments.html',
#    'connectors.html',
#    'default-servlet.html',
#    'deployer-howto.html',
#    'developers.html',
#    'graal.html',
#    'host-manager-howto.html',
#    'html-host-manager-howto.html',
#    'html-manager-howto.html',
#    'index.html',
#    'introduction.html',
#    'jasper-howto.html',
#    'jdbc-pool.html',
#    'jndi-datasource-examples-howto.html',
#    'jndi-resources-howto.html',
#    'logging.html',
#    'manager-howto.html',
#    'maven-jars.html',
#    'mbeans-descriptors-howto.html',
#    'mbeans-descriptors.dtd',
#    'monitoring.html',
#    'proxy-howto.html',
#    'realm-howto.html',
#    'RELEASE-NOTES.txt',
#    'rewrite.html',
#    'RUNNING.txt',
#    'security-howto.html',
#    'security-manager-howto.html',
#    'setup.html',
#    'ssi-howto.html',
#    'ssl-howto.html',
#    'virtual-hosting-howto.html',
#    'web-socket-howto.html',
#    'windows-auth-howto.html',
#    'windows-service-howto.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\annotationapi',
#   [],
#   ['index.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\api', [], ['index.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\appdev',
#   ['sample'],
#   ['build.xml.txt',
#    'deployment.html',
#    'index.html',
#    'installation.html',
#    'introduction.html',
#    'processes.html',
#    'source.html',
#    'web.xml.txt']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\appdev\\sample',
#   ['docs', 'src', 'web'],
#   ['build.xml', 'index.html', 'sample.war']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\appdev\\sample\\docs',
#   [],
#   ['README.txt']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\appdev\\sample\\src',
#   ['mypackage'],
#   []),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\appdev\\sample\\src\\mypackage',
#   [],
#   ['Hello.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\appdev\\sample\\web',
#   ['images', 'WEB-INF'],
#   ['hello.jsp', 'index.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\appdev\\sample\\web\\images',
#   [],
#   ['tomcat.gif']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\appdev\\sample\\web\\WEB-INF',
#   [],
#   ['web.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\architecture',
#   ['requestProcess', 'startup'],
#   ['index.html', 'overview.html', 'requestProcess.html', 'startup.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\architecture\\requestProcess',
#   [],
#   ['authentication-process.png', 'request-process.png']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\architecture\\startup',
#   [],
#   ['serverStartup.pdf', 'serverStartup.txt']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\config',
#   [],
#   ['ajp.html',
#    'automatic-deployment.html',
#    'cluster-channel.html',
#    'cluster-deployer.html',
#    'cluster-interceptor.html',
#    'cluster-listener.html',
#    'cluster-manager.html',
#    'cluster-membership.html',
#    'cluster-receiver.html',
#    'cluster-sender.html',
#    'cluster-valve.html',
#    'cluster.html',
#    'context.html',
#    'cookie-processor.html',
#    'credentialhandler.html',
#    'engine.html',
#    'executor.html',
#    'filter.html',
#    'globalresources.html',
#    'host.html',
#    'http.html',
#    'http2.html',
#    'index.html',
#    'jar-scan-filter.html',
#    'jar-scanner.html',
#    'jaspic.html',
#    'listeners.html',
#    'loader.html',
#    'manager.html',
#    'realm.html',
#    'resources.html',
#    'server.html',
#    'service.html',
#    'sessionidgenerator.html',
#    'systemprops.html',
#    'valve.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\elapi',
#   [],
#   ['index.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\images',
#   ['fonts'],
#   ['add.gif',
#    'asf-logo.svg',
#    'code.gif',
#    'cors-flowchart.png',
#    'design.gif',
#    'docs-stylesheet.css',
#    'docs.gif',
#    'fix.gif',
#    'tomcat.gif',
#    'tomcat.png',
#    'update.gif',
#    'void.gif']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\images\\fonts',
#   [],
#   ['fonts.css',
#    'OpenSans400.woff',
#    'OpenSans400italic.woff',
#    'OpenSans600.woff',
#    'OpenSans600italic.woff',
#    'OpenSans700.woff',
#    'OpenSans700italic.woff']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\jaspicapi',
#   [],
#   ['index.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\jspapi',
#   [],
#   ['index.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\META-INF',
#   [],
#   ['context.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\servletapi',
#   [],
#   ['index.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\tribes',
#   [],
#   ['developers.html',
#    'faq.html',
#    'interceptors.html',
#    'introduction.html',
#    'membership.html',
#    'setup.html',
#    'status.html',
#    'transport.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\WEB-INF',
#   ['jsp'],
#   ['web.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\WEB-INF\\jsp',
#   [],
#   ['403.jsp']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\docs\\websocketapi',
#   [],
#   ['index.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples',
#   ['jsp', 'META-INF', 'servlets', 'WEB-INF', 'websocket'],
#   ['index.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp',
#   ['async',
#    'cal',
#    'checkbox',
#    'colors',
#    'dates',
#    'error',
#    'forward',
#    'images',
#    'include',
#    'jsp2',
#    'jsptoserv',
#    'num',
#    'security',
#    'sessions',
#    'simpletag',
#    'snp',
#    'tagplugin',
#    'xml'],
#   ['index.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\async',
#   [],
#   ['async1.jsp',
#    'async1.jsp.html',
#    'async3.jsp',
#    'async3.jsp.html',
#    'index.jsp',
#    'index.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\cal',
#   [],
#   ['cal1.jsp',
#    'cal1.jsp.html',
#    'cal2.jsp',
#    'cal2.jsp.html',
#    'calendar.html',
#    'Entries.java.html',
#    'Entry.java.html',
#    'JspCalendar.java.html',
#    'login.html',
#    'TableBean.java.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\checkbox',
#   [],
#   ['check.html',
#    'checkresult.jsp',
#    'checkresult.jsp.html',
#    'CheckTest.html',
#    'cresult.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\colors',
#   [],
#   ['clr.html',
#    'ColorGameBean.html',
#    'colors.html',
#    'colrs.jsp',
#    'colrs.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\dates',
#   [],
#   ['date.html', 'date.jsp', 'date.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\error',
#   [],
#   ['er.html',
#    'err.jsp',
#    'err.jsp.html',
#    'error.html',
#    'errorpge.jsp',
#    'errorpge.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\forward',
#   [],
#   ['forward.jsp',
#    'forward.jsp.html',
#    'fwd.html',
#    'one.jsp',
#    'one.jsp.html',
#    'two.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\images',
#   [],
#   ['code.gif', 'execute.gif', 'return.gif']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\include',
#   [],
#   ['foo.html',
#    'foo.jsp',
#    'foo.jsp.html',
#    'inc.html',
#    'include.jsp',
#    'include.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\jsp2',
#   ['el', 'jspattribute', 'jspx', 'misc', 'simpletag', 'tagfiles'],
#   []),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\jsp2\\el',
#   [],
#   ['basic-arithmetic.html',
#    'basic-arithmetic.jsp',
#    'basic-arithmetic.jsp.html',
#    'basic-comparisons.html',
#    'basic-comparisons.jsp',
#    'basic-comparisons.jsp.html',
#    'composite.html',
#    'composite.jsp',
#    'composite.jsp.html',
#    'functions.html',
#    'Functions.java.html',
#    'functions.jsp',
#    'functions.jsp.html',
#    'implicit-objects.html',
#    'implicit-objects.jsp',
#    'implicit-objects.jsp.html',
#    'ValuesBean.java.html',
#    'ValuesTag.java.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\jsp2\\jspattribute',
#   [],
#   ['FooBean.java.html',
#    'HelloWorldSimpleTag.java.html',
#    'jspattribute.html',
#    'jspattribute.jsp',
#    'jspattribute.jsp.html',
#    'shuffle.html',
#    'shuffle.jsp',
#    'shuffle.jsp.html',
#    'ShuffleSimpleTag.java.html',
#    'TileSimpleTag.java.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\jsp2\\jspx',
#   [],
#   ['basic.html',
#    'basic.jspx',
#    'basic.jspx.html',
#    'svgexample.html',
#    'textRotate.html',
#    'textRotate.jpg',
#    'textRotate.jspx',
#    'textRotate.jspx.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\jsp2\\misc',
#   [],
#   ['coda.jspf',
#    'coda.jspf.html',
#    'config.html',
#    'config.jsp',
#    'config.jsp.html',
#    'dynamicattrs.html',
#    'dynamicattrs.jsp',
#    'dynamicattrs.jsp.html',
#    'EchoAttributesTag.java.html',
#    'prelude.jspf',
#    'prelude.jspf.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\jsp2\\simpletag',
#   [],
#   ['book.html',
#    'book.jsp',
#    'book.jsp.html',
#    'BookBean.java.html',
#    'FindBookSimpleTag.java.html',
#    'Functions.java.html',
#    'hello.html',
#    'hello.jsp',
#    'hello.jsp.html',
#    'HelloWorldSimpleTag.java.html',
#    'repeat.html',
#    'repeat.jsp',
#    'repeat.jsp.html',
#    'RepeatSimpleTag.java.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\jsp2\\tagfiles',
#   [],
#   ['displayProducts.tag.html',
#    'hello.html',
#    'hello.jsp',
#    'hello.jsp.html',
#    'helloWorld.tag.html',
#    'panel.html',
#    'panel.jsp',
#    'panel.jsp.html',
#    'panel.tag.html',
#    'products.html',
#    'products.jsp',
#    'products.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\jsptoserv',
#   [],
#   ['hello.jsp',
#    'hello.jsp.html',
#    'jsptoservlet.jsp',
#    'jsptoservlet.jsp.html',
#    'jts.html',
#    'ServletToJsp.java.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\num',
#   [],
#   ['numguess.html', 'numguess.jsp', 'numguess.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\security',
#   ['protected'],
#   []),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\security\\protected',
#   [],
#   ['error.jsp',
#    'error.jsp.html',
#    'index.jsp',
#    'index.jsp.html',
#    'login.jsp',
#    'login.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\sessions',
#   [],
#   ['carts.html', 'carts.jsp', 'carts.jsp.html', 'crt.html', 'DummyCart.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\simpletag',
#   [],
#   ['foo.html', 'foo.jsp', 'foo.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\snp',
#   [],
#   ['snoop.html', 'snoop.jsp', 'snoop.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\tagplugin',
#   [],
#   ['choose.html',
#    'choose.jsp',
#    'choose.jsp.html',
#    'foreach.html',
#    'foreach.jsp',
#    'foreach.jsp.html',
#    'howto.html',
#    'if.html',
#    'if.jsp',
#    'if.jsp.html',
#    'notes.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\jsp\\xml',
#   [],
#   ['xml.html', 'xml.jsp', 'xml.jsp.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\META-INF',
#   [],
#   ['context.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\servlets',
#   ['images', 'nonblocking'],
#   ['cookies.html',
#    'helloworld.html',
#    'index.html',
#    'reqheaders.html',
#    'reqinfo.html',
#    'reqparams.html',
#    'sessions.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\servlets\\images',
#   [],
#   ['code.gif', 'execute.gif', 'return.gif']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\servlets\\nonblocking',
#   [],
#   ['bytecounter.html']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF',
#   ['classes', 'jsp', 'lib', 'tags'],
#   ['web.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes',
#   ['async',
#    'cal',
#    'checkbox',
#    'colors',
#    'compressionFilters',
#    'dates',
#    'error',
#    'examples',
#    'filters',
#    'http2',
#    'jsp2',
#    'listeners',
#    'nonblocking',
#    'num',
#    'sessions',
#    'trailers',
#    'util',
#    'validators',
#    'websocket'],
#   ['CookieExample.class',
#    'CookieExample.java',
#    'HelloWorldExample.class',
#    'HelloWorldExample.java',
#    'LocalStrings.properties',
#    'LocalStrings_cs.properties',
#    'LocalStrings_de.properties',
#    'LocalStrings_es.properties',
#    'LocalStrings_fr.properties',
#    'LocalStrings_ja.properties',
#    'LocalStrings_ko.properties',
#    'LocalStrings_pt.properties',
#    'LocalStrings_pt_BR.properties',
#    'LocalStrings_ru.properties',
#    'LocalStrings_zh_CN.properties',
#    'RequestHeaderExample.class',
#    'RequestHeaderExample.java',
#    'RequestInfoExample.class',
#    'RequestInfoExample.java',
#    'RequestParamExample.class',
#    'RequestParamExample.java',
#    'ServletToJsp.class',
#    'ServletToJsp.java',
#    'SessionExample.class',
#    'SessionExample.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\async',
#   [],
#   ['Async0$1.class',
#    'Async0.class',
#    'Async0.java',
#    'Async1$1.class',
#    'Async1.class',
#    'Async1.java',
#    'Async2$1.class',
#    'Async2.class',
#    'Async2.java',
#    'Async3.class',
#    'Async3.java',
#    'AsyncStockContextListener.class',
#    'AsyncStockContextListener.java',
#    'AsyncStockServlet.class',
#    'AsyncStockServlet.java',
#    'Stockticker$Stock.class',
#    'Stockticker$TickListener.class',
#    'Stockticker.class',
#    'Stockticker.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\cal',
#   [],
#   ['Entries.class',
#    'Entries.java',
#    'Entry.class',
#    'Entry.java',
#    'JspCalendar.class',
#    'JspCalendar.java',
#    'TableBean.class',
#    'TableBean.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\checkbox',
#   [],
#   ['CheckTest.class', 'CheckTest.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\colors',
#   [],
#   ['ColorGameBean.class', 'ColorGameBean.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\compressionFilters',
#   [],
#   ['CompressionFilter.class',
#    'CompressionFilter.java',
#    'CompressionFilterTestServlet.class',
#    'CompressionFilterTestServlet.java',
#    'CompressionResponseStream.class',
#    'CompressionResponseStream.java',
#    'CompressionServletResponseWrapper.class',
#    'CompressionServletResponseWrapper.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\dates',
#   [],
#   ['JspCalendar.class', 'JspCalendar.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\error',
#   [],
#   ['Smart.class', 'Smart.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\examples',
#   [],
#   ['ExampleTagBase.class',
#    'ExampleTagBase.java',
#    'FooTag.class',
#    'FooTag.java',
#    'FooTagExtraInfo.class',
#    'FooTagExtraInfo.java',
#    'LogTag.class',
#    'LogTag.java',
#    'ValuesTag.class',
#    'ValuesTag.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\filters',
#   [],
#   ['ExampleFilter.class', 'ExampleFilter.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\http2',
#   [],
#   ['SimpleImagePush.class', 'SimpleImagePush.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\jsp2',
#   ['examples'],
#   []),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\jsp2\\examples',
#   ['el', 'simpletag'],
#   ['BookBean.class',
#    'BookBean.java',
#    'FooBean.class',
#    'FooBean.java',
#    'ValuesBean.class',
#    'ValuesBean.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\jsp2\\examples\\el',
#   [],
#   ['Functions.class', 'Functions.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\jsp2\\examples\\simpletag',
#   [],
#   ['EchoAttributesTag.class',
#    'EchoAttributesTag.java',
#    'FindBookSimpleTag.class',
#    'FindBookSimpleTag.java',
#    'HelloWorldSimpleTag.class',
#    'HelloWorldSimpleTag.java',
#    'RepeatSimpleTag.class',
#    'RepeatSimpleTag.java',
#    'ShuffleSimpleTag.class',
#    'ShuffleSimpleTag.java',
#    'TileSimpleTag.class',
#    'TileSimpleTag.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\listeners',
#   [],
#   ['ContextListener.class',
#    'ContextListener.java',
#    'SessionListener.class',
#    'SessionListener.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\nonblocking',
#   [],
#   ['ByteCounter$CounterListener.class',
#    'ByteCounter.class',
#    'ByteCounter.java',
#    'NumberWriter$NumberWriterListener.class',
#    'NumberWriter.class',
#    'NumberWriter.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\num',
#   [],
#   ['NumberGuessBean.class', 'NumberGuessBean.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\sessions',
#   [],
#   ['DummyCart.class', 'DummyCart.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\trailers',
#   [],
#   ['ResponseTrailers$TrailerFieldSupplier.class',
#    'ResponseTrailers.class',
#    'ResponseTrailers.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\util',
#   [],
#   ['CookieFilter.class',
#    'CookieFilter.java',
#    'HTMLFilter.class',
#    'HTMLFilter.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\validators',
#   [],
#   ['DebugValidator.class', 'DebugValidator.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\websocket',
#   ['chat', 'drawboard', 'echo', 'snake'],
#   ['ExamplesConfig.class', 'ExamplesConfig.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\websocket\\chat',
#   [],
#   ['ChatAnnotation.class', 'ChatAnnotation.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\websocket\\drawboard',
#   ['wsmessages'],
#   ['Client$1.class',
#    'Client.class',
#    'Client.java',
#    'DrawboardContextListener.class',
#    'DrawboardContextListener.java',
#    'DrawboardEndpoint$1.class',
#    'DrawboardEndpoint$2.class',
#    'DrawboardEndpoint$3$1.class',
#    'DrawboardEndpoint$3.class',
#    'DrawboardEndpoint.class',
#    'DrawboardEndpoint.java',
#    'DrawMessage$ParseException.class',
#    'DrawMessage.class',
#    'DrawMessage.java',
#    'Room$1$1.class',
#    'Room$1.class',
#    'Room$2.class',
#    'Room$MessageType.class',
#    'Room$Player.class',
#    'Room.class',
#    'Room.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\websocket\\drawboard\\wsmessages',
#   [],
#   ['AbstractWebsocketMessage.class',
#    'AbstractWebsocketMessage.java',
#    'BinaryWebsocketMessage.class',
#    'BinaryWebsocketMessage.java',
#    'CloseWebsocketMessage.class',
#    'CloseWebsocketMessage.java',
#    'StringWebsocketMessage.class',
#    'StringWebsocketMessage.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\websocket\\echo',
#   [],
#   ['EchoAnnotation.class',
#    'EchoAnnotation.java',
#    'EchoAsyncAnnotation$CompletedFuture.class',
#    'EchoAsyncAnnotation.class',
#    'EchoAsyncAnnotation.java',
#    'EchoEndpoint$EchoMessageHandlerBinary.class',
#    'EchoEndpoint$EchoMessageHandlerText.class',
#    'EchoEndpoint.class',
#    'EchoEndpoint.java',
#    'EchoStreamAnnotation.class',
#    'EchoStreamAnnotation.java',
#    'servers.json']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\classes\\websocket\\snake',
#   [],
#   ['Direction.class',
#    'Direction.java',
#    'Location$1.class',
#    'Location.class',
#    'Location.java',
#    'Snake.class',
#    'Snake.java',
#    'SnakeAnnotation.class',
#    'SnakeAnnotation.java',
#    'SnakeTimer$1.class',
#    'SnakeTimer.class',
#    'SnakeTimer.java']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\jsp',
#   [],
#   ['403.jsp',
#    '403.jsp.html',
#    'debug-taglib.tld',
#    'example-taglib.tld',
#    'jsp2-example-taglib.tld']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\lib',
#   [],
#   ['taglibs-standard-impl-1.2.5-migrated-0.0.1.jar',
#    'taglibs-standard-spec-1.2.5-migrated-0.0.1.jar']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\WEB-INF\\tags',
#   [],
#   ['displayProducts.tag', 'helloWorld.tag', 'panel.tag']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\examples\\websocket',
#   [],
#   ['chat.xhtml',
#    'drawboard.xhtml',
#    'echo.xhtml',
#    'index.xhtml',
#    'snake.xhtml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\host-manager',
#   ['css', 'images', 'META-INF', 'WEB-INF'],
#   ['index.jsp']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\host-manager\\css',
#   [],
#   ['manager.css']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\host-manager\\images',
#   [],
#   ['asf-logo.svg', 'tomcat.svg']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\host-manager\\META-INF',
#   [],
#   ['context.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\host-manager\\WEB-INF',
#   ['jsp'],
#   ['manager.xml', 'web.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\host-manager\\WEB-INF\\jsp',
#   [],
#   ['401.jsp', '403.jsp', '404.jsp']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\manager',
#   ['css', 'images', 'META-INF', 'WEB-INF'],
#   ['index.jsp', 'status.xsd', 'xform.xsl']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\manager\\css',
#   [],
#   ['manager.css']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\manager\\images',
#   [],
#   ['asf-logo.svg', 'tomcat.svg']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\manager\\META-INF',
#   [],
#   ['context.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\manager\\WEB-INF',
#   ['jsp'],
#   ['web.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\manager\\WEB-INF\\jsp',
#   [],
#   ['401.jsp',
#    '403.jsp',
#    '404.jsp',
#    'connectorCerts.jsp',
#    'connectorCiphers.jsp',
#    'connectorTrustedCerts.jsp',
#    'sessionDetail.jsp',
#    'sessionsList.jsp']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\ROOT',
#   ['WEB-INF'],
#   ['asf-logo-wide.svg',
#    'bg-button.png',
#    'bg-middle.png',
#    'bg-nav.png',
#    'bg-upper.png',
#    'favicon.ico',
#    'index.jsp',
#    'RELEASE-NOTES.txt',
#    'tomcat.css',
#    'tomcat.svg']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\webapps\\ROOT\\WEB-INF', [], ['web.xml']),
#  ('c:\\apache\\apache-tomcat-10.1.8\\work', [], []),
#  ('c:\\apache-maven-3.9.4',
#   ['bin', 'boot', 'conf', 'lib'],
#   ['LICENSE', 'NOTICE', 'README.txt']),
#  ('c:\\apache-maven-3.9.4\\bin',
#   [],
#   ['m2.conf', 'mvn', 'mvn.cmd', 'mvnDebug', 'mvnDebug.cmd', 'mvnyjp']),
#  ('c:\\apache-maven-3.9.4\\boot',
#   [],
#   ['plexus-classworlds-2.7.0.jar', 'plexus-classworlds.license']),
#  ('c:\\apache-maven-3.9.4\\conf',
#   ['logging'],
#   ['settings.xml', 'toolchains.xml']),
#  ('c:\\apache-maven-3.9.4\\conf\\logging', [], ['simplelogger.properties']),
#  ('c:\\apache-maven-3.9.4\\lib',
#   ['ext', 'jansi-native'],
#   ['aopalliance-1.0.jar',
#    'aopalliance.license',
#    'commons-cli-1.5.0.jar',
#    'commons-cli.license',
#    'commons-codec-1.11.jar',
#    'commons-codec.license',
#    'commons-lang3-3.12.0.jar',
#    'commons-lang3.license',
#    'failureaccess-1.0.1.jar',
#    'failureaccess.license',
#    'guava-32.0.1-jre.jar',
#    'guava.license',
#    'guice-5.1.0.jar',
#    'guice.license',
#    'httpclient-4.5.14.jar',
#    'httpclient.license',
#    'httpcore-4.4.16.jar',
#    'httpcore.license',
#    'jansi-2.4.0.jar',
#    'jansi.license',
#    'javax.annotation-api-1.3.2.jar',
#    'javax.annotation-api.license',
#    'javax.inject-1.jar',
#    'javax.inject.license',
#    'jcl-over-slf4j-1.7.36.jar',
#    'jcl-over-slf4j.license',
#    'maven-artifact-3.9.4.jar',
#    'maven-builder-support-3.9.4.jar',
#    'maven-compat-3.9.4.jar',
#    'maven-core-3.9.4.jar',
#    'maven-embedder-3.9.4.jar',
#    'maven-model-3.9.4.jar',
#    'maven-model-builder-3.9.4.jar',
#    'maven-plugin-api-3.9.4.jar',
#    'maven-repository-metadata-3.9.4.jar',
#    'maven-resolver-api-1.9.14.jar',
#    'maven-resolver-connector-basic-1.9.14.jar',
#    'maven-resolver-impl-1.9.14.jar',
#    'maven-resolver-named-locks-1.9.14.jar',
#    'maven-resolver-provider-3.9.4.jar',
#    'maven-resolver-spi-1.9.14.jar',
#    'maven-resolver-transport-file-1.9.14.jar',
#    'maven-resolver-transport-http-1.9.14.jar',
#    'maven-resolver-transport-wagon-1.9.14.jar',
#    'maven-resolver-util-1.9.14.jar',
#    'maven-settings-3.9.4.jar',
#    'maven-settings-builder-3.9.4.jar',
#    'maven-shared-utils-3.3.4.jar',
#    'maven-slf4j-provider-3.9.4.jar',
#    'org.eclipse.sisu.inject-0.3.5.jar',
#    'org.eclipse.sisu.inject.license',
#    'org.eclipse.sisu.plexus-0.3.5.jar',
#    'org.eclipse.sisu.plexus.license',
#    'plexus-cipher-2.0.jar',
#    'plexus-cipher.license',
#    'plexus-component-annotations-2.1.0.jar',
#    'plexus-component-annotations.license',
#    'plexus-interpolation-1.26.jar',
#    'plexus-interpolation.license',
#    'plexus-sec-dispatcher-2.0.jar',
#    'plexus-sec-dispatcher.license',
#    'plexus-utils-3.5.1.jar',
#    'plexus-utils.license',
#    'slf4j-api-1.7.36.jar',
#    'slf4j-api.license',
#    'wagon-file-3.5.3.jar',
#    'wagon-http-3.5.3.jar',
#    'wagon-http-shared-3.5.3.jar',
#    'wagon-provider-api-3.5.3.jar']),
#  ('c:\\apache-maven-3.9.4\\lib\\ext',
#   ['hazelcast', 'redisson'],
#   ['README.txt']),
#  ('c:\\apache-maven-3.9.4\\lib\\ext\\hazelcast', [], ['README.txt']),
#  ('c:\\apache-maven-3.9.4\\lib\\ext\\redisson', [], ['README.txt']),
#  ('c:\\apache-maven-3.9.4\\lib\\jansi-native', ['Windows'], ['README.txt']),
#  ('c:\\apache-maven-3.9.4\\lib\\jansi-native\\Windows', ['x86', 'x86_64'], []),
#  ('c:\\apache-maven-3.9.4\\lib\\jansi-native\\Windows\\x86',
#   [],
#   ['jansi.dll']),
#  ('c:\\apache-maven-3.9.4\\lib\\jansi-native\\Windows\\x86_64',
#   [],
#   ['jansi.dll']),
#  ('c:\\app', ['prade'], []),
#  ('c:\\app\\prade', ['product', 'virtual'], []),
#  ('c:\\app\\prade\\product', ['12.1.0'], []),
#  ('c:\\app\\prade\\product\\12.1.0', ['dbhome_1'], []),
#  ('c:\\app\\prade\\product\\12.1.0\\dbhome_1', ['BIN'], []),
#  ('c:\\app\\prade\\product\\12.1.0\\dbhome_1\\BIN',
#   [],
#   ['libmmd.dll',
#    'oci.dll',
#    'oraasmclnt12.dll',
#    'oracell12.dll',
#    'oracle.exe',
#    'oraclient12.dll',
#    'oraclsce12.dll',
#    'oraclsra12.dll',
#    'oracommon12.dll',
#    'oracore12.dll',
#    'orageneric12.dll',
#    'orahasgen12.dll',
#    'oraldapclnt12.dll',
#    'oran12.dll',
#    'orancds12.dll',
#    'orancrypt12.dll',
#    'oranhost12.dll',
#    'oranl12.dll',
#    'oranldap12.dll',
#    'oranls12.dll',
#    'orannzsbb12.dll',
#    'oranro12.dll',
#    'oransgr12.dll',
#    'orantcp12.dll',
#    'orantns12.dll',
#    'oraocr12.dll',
#    'oraocrb12.dll',
#    'oraocrutl12.dll',
#    'oraons.dll',
#    'oraplc12.dll',
#    'oraplp12.dll',
#    'orapls12.dll',
#    'oraskjcx12.dll',
#    'ORASLAX12.DLL',
#    'orasnls12.dll',
#    'orasql12.dll',
#    'oraunls12.dll',
#    'orauts.dll',
#    'oravsn12.dll',
#    'oravssw.exe',
#    'orawsec12.dll',
#    'orawwg.dll',
#    'oraxml12.dll',
#    'orazt12.dll',
#    'oraztkg12.dll']),
#  ('c:\\app\\prade\\virtual', ['product'], []),
#  ('c:\\app\\prade\\virtual\\product', ['12.2.0'], []),
#  ('c:\\app\\prade\\virtual\\product\\12.2.0', ['dbhome_1'], []),
#  ('c:\\app\\prade\\virtual\\product\\12.2.0\\dbhome_1', ['bin'], []),
#  ('c:\\app\\prade\\virtual\\product\\12.2.0\\dbhome_1\\bin',
#   [],
#   ['libmmd.dll',
#    'msvcr120.dll',
#    'oci.dll',
#    'oraasmclnt12.dll',
#    'oracell12.dll',
#    'oracle.exe',
#    'oraclient12.dll',
#    'oraclsce12.dll',
#    'oraclsra12.dll',
#    'oracommon12.dll',
#    'oracore12.dll',
#    'orageneric12.dll',
#    'orahasgen12.dll',
#    'oraldapclnt12.dll',
#    'oran12.dll',
#    'orancds12.dll',
#    'orancrypt12.dll',
#    'orangsmshd12.dll',
#    'oranhost12.dll',
#    'oranl12.dll',
#    'oranldap12.dll',
#    'oranls12.dll',
#    'orannzsbb12.dll',
#    'oranro12.dll',
#    'oransgr12.dll',
#    'orantcp12.dll',
#    'orantns12.dll',
#    'oraocr12.dll',
#    'oraocrb12.dll',
#    'oraocrutl12.dll',
#    'oraodm12.dll',
#    'oraofs.dll',
#    'oraons.dll',
#    'oraplp12.dll',
#    'orapls12.dll',
#    'oraskjcx12.dll',
#    'ORASLAX12.DLL',
#    'orasnls12.dll',
#    'orasql12.dll',
#    'oraunls12.dll',
#    'orauts.dll',
#    'oravsn12.dll',
#    'orawsec12.dll',
#    'orawwg.dll',
#    'oraxml12.dll',
#    'orazt12.dll',
#    'oraztkg12.dll']),
#  ('c:\\AtomicRedTeam', ['invoke-atomicredteam'], []),
#  ('c:\\AtomicRedTeam\\invoke-atomicredteam',
#   ['.github', 'Private', 'Public'],
#   ['CODE_OF_CONDUCT.md',
#    'install-atomicredteam.ps1',
#    'install-atomicsfolder.ps1',
#    'Invoke-AtomicRedTeam.psd1',
#    'Invoke-AtomicRedTeam.psm1',
#    'LICENSE.txt',
#    'README.md']),
#  ('c:\\AtomicRedTeam\\invoke-atomicredteam\\.github', ['workflows'], []),
#  ('c:\\AtomicRedTeam\\invoke-atomicredteam\\.github\\workflows',
#   [],
#   ['publish-powershell-gallery.yml']),
#  ('c:\\AtomicRedTeam\\invoke-atomicredteam\\Private',
#   [],
#   ['.gitkeep',
#    'AtomicClassSchema.ps1',
#    'Get-PrereqExecutor.ps1',
#    'Get-TargetInfo.ps1',
#    'Invoke-CheckPrereqs.ps1',
#    'Invoke-ExecuteCommand.ps1',
#    'Invoke-KillProcessTree.ps1',
#    'Invoke-Process.ps1',
#    'Replace-InputArgs.ps1',
#    'Show-Details.ps1',
#    'Write-KeyValue.ps1',
#    'Write-PrereqResults.ps1']),
#  ('c:\\AtomicRedTeam\\invoke-atomicredteam\\Public',
#   [],
#   ['Default-ExecutionLogger.psm1',
#    'Get-AtomicTechnique.ps1',
#    'Invoke-AtomicTest.ps1',
#    'Invoke-FetchFromZip.ps1',
#    'Invoke-WebRequestVerifyHash.ps1',
#    'New-Atomic.ps1',
#    'Start-AtomicGUI.ps1']),
#  ('c:\\attackworkbench',
#   ['attack-workbench-collection-manager',
#    'attack-workbench-frontend',
#    'attack-workbench-rest-api'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager',
#   ['.git', 'app', 'bin', 'docs'],
#   ['.dockerignore',
#    '.eslintrc.yml',
#    '.gitignore',
#    '.nvmrc',
#    'Dockerfile',
#    'legacy-domains.md',
#    'LICENSE.txt',
#    'NOTICE.txt',
#    'package-lock.json',
#    'package.json',
#    'README.md']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git',
#   ['hooks', 'info', 'logs', 'objects', 'refs'],
#   ['config', 'description', 'HEAD', 'index', 'packed-refs']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\hooks',
#   [],
#   ['applypatch-msg.sample',
#    'commit-msg.sample',
#    'fsmonitor-watchman.sample',
#    'post-update.sample',
#    'pre-applypatch.sample',
#    'pre-commit.sample',
#    'pre-merge-commit.sample',
#    'pre-push.sample',
#    'pre-rebase.sample',
#    'pre-receive.sample',
#    'prepare-commit-msg.sample',
#    'push-to-checkout.sample',
#    'update.sample']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\info',
#   [],
#   ['exclude']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\logs',
#   ['refs'],
#   ['HEAD']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\logs\\refs',
#   ['heads', 'remotes'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\logs\\refs\\heads',
#   [],
#   ['master']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\logs\\refs\\remotes',
#   ['origin'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\logs\\refs\\remotes\\origin',
#   [],
#   ['HEAD']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\objects',
#   ['info', 'pack'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\objects\\info',
#   [],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\objects\\pack',
#   [],
#   ['pack-94b8f132a2b1977a10dd4fc50678a8e6e5353e82.idx',
#    'pack-94b8f132a2b1977a10dd4fc50678a8e6e5353e82.pack']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\refs',
#   ['heads', 'remotes', 'tags'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\refs\\heads',
#   [],
#   ['master']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\refs\\remotes',
#   ['origin'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\refs\\remotes\\origin',
#   [],
#   ['HEAD']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\.git\\refs\\tags',
#   [],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\app',
#   ['api', 'config', 'controllers', 'lib', 'routes', 'scheduler', 'services'],
#   ['index.js']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\app\\api',
#   ['definitions'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\app\\api\\definitions',
#   [],
#   ['openapi.yml']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\app\\config',
#   [],
#   ['config.js']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\app\\controllers',
#   [],
#   ['collection-indexes-controller.js', 'collections-controller.js']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\app\\lib',
#   [],
#   ['error-handler.js', 'logger.js']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\app\\routes',
#   [],
#   ['collection-indexes-routes.js', 'collections-routes.js', 'index.js']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\app\\scheduler',
#   [],
#   ['scheduler.js']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\app\\services',
#   [],
#   ['collection-indexes-service.js', 'collections-service.js']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\bin',
#   [],
#   ['www']),
#  ('c:\\attackworkbench\\attack-workbench-collection-manager\\docs',
#   [],
#   ['CONTRIBUTING.md', 'docker.md', 'README.md']),
#  ('c:\\attackworkbench\\attack-workbench-frontend',
#   ['.git', 'app', 'docs', 'nginx'],
#   ['.dockerignore',
#    '.gitignore',
#    'docker-compose.certs.yml',
#    'docker-compose.yml',
#    'Dockerfile',
#    'LICENSE.txt',
#    'NOTICE.txt',
#    'README.md']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git',
#   ['hooks', 'info', 'logs', 'objects', 'refs'],
#   ['config', 'description', 'HEAD', 'index', 'packed-refs']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\hooks',
#   [],
#   ['applypatch-msg.sample',
#    'commit-msg.sample',
#    'fsmonitor-watchman.sample',
#    'post-update.sample',
#    'pre-applypatch.sample',
#    'pre-commit.sample',
#    'pre-merge-commit.sample',
#    'pre-push.sample',
#    'pre-rebase.sample',
#    'pre-receive.sample',
#    'prepare-commit-msg.sample',
#    'push-to-checkout.sample',
#    'update.sample']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\info',
#   [],
#   ['exclude']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\logs',
#   ['refs'],
#   ['HEAD']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\logs\\refs',
#   ['heads', 'remotes'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\logs\\refs\\heads',
#   [],
#   ['master']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\logs\\refs\\remotes',
#   ['origin'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\logs\\refs\\remotes\\origin',
#   [],
#   ['HEAD']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\objects',
#   ['info', 'pack'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\objects\\info',
#   [],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\objects\\pack',
#   [],
#   ['pack-7c6861d2a5871ab1450ea93d1653eb35a29d5878.idx',
#    'pack-7c6861d2a5871ab1450ea93d1653eb35a29d5878.pack']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\refs',
#   ['heads', 'remotes', 'tags'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\refs\\heads',
#   [],
#   ['master']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\refs\\remotes',
#   ['origin'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\refs\\remotes\\origin',
#   [],
#   ['HEAD']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\.git\\refs\\tags', [], []),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app',
#   ['e2e', 'src'],
#   ['.browserslistrc',
#    '.editorconfig',
#    '.gitignore',
#    'angular.json',
#    'karma.conf.js',
#    'package-lock.json',
#    'package.json',
#    'tsconfig.app.json',
#    'tsconfig.json',
#    'tsconfig.spec.json',
#    'tslint.json']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\e2e',
#   ['src'],
#   ['protractor.conf.js', 'tsconfig.json']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\e2e\\src',
#   [],
#   ['app.e2e-spec.ts', 'app.po.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src',
#   ['app', 'assets', 'environments', 'style'],
#   ['favicon.ico',
#    'favicon.png',
#    'index.html',
#    'main.ts',
#    'polyfills.ts',
#    'test.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app',
#   ['classes', 'components', 'services', 'util', 'views'],
#   ['app-routing-stix.module.ts',
#    'app-routing.module.ts',
#    'app.component.html',
#    'app.component.scss',
#    'app.component.spec.ts',
#    'app.component.ts',
#    'app.module.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\classes',
#   ['stix'],
#   ['collection-index.ts',
#    'external-references.ts',
#    'serializable.ts',
#    'version-number.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\classes\\stix',
#   [],
#   ['collection.ts',
#    'group.ts',
#    'identity.ts',
#    'marking-definition.ts',
#    'matrix.ts',
#    'mitigation.ts',
#    'note.ts',
#    'relationship.ts',
#    'software.ts',
#    'stix-object.ts',
#    'tactic.ts',
#    'technique.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components',
#   ['add-dialog',
#    'add-relationship-button',
#    'collection-import-summary',
#    'confirmation-dialog',
#    'empty-list-marker',
#    'footer',
#    'header',
#    'loading-overlay',
#    'markdown-view-dialog',
#    'multiple-choice-dialog',
#    'object-status',
#    'resources-drawer',
#    'save-dialog',
#    'stix',
#    'subheading',
#    'toolbar',
#    'validation-results'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\add-dialog',
#   [],
#   ['add-dialog.component.html',
#    'add-dialog.component.scss',
#    'add-dialog.component.spec.ts',
#    'add-dialog.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\add-relationship-button',
#   [],
#   ['add-relationship-button.component.html',
#    'add-relationship-button.component.scss',
#    'add-relationship-button.component.spec.ts',
#    'add-relationship-button.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\collection-import-summary',
#   [],
#   ['collection-import-summary.component.html',
#    'collection-import-summary.component.scss',
#    'collection-import-summary.component.spec.ts',
#    'collection-import-summary.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\confirmation-dialog',
#   [],
#   ['confirmation-dialog.component.html',
#    'confirmation-dialog.component.scss',
#    'confirmation-dialog.component.spec.ts',
#    'confirmation-dialog.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\empty-list-marker',
#   [],
#   ['empty-list-marker.component.html',
#    'empty-list-marker.component.scss',
#    'empty-list-marker.component.spec.ts',
#    'empty-list-marker.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\footer',
#   [],
#   ['footer.component.html',
#    'footer.component.scss',
#    'footer.component.spec.ts',
#    'footer.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\header',
#   [],
#   ['header.component.html',
#    'header.component.scss',
#    'header.component.spec.ts',
#    'header.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\loading-overlay',
#   [],
#   ['loading-overlay.component.html',
#    'loading-overlay.component.scss',
#    'loading-overlay.component.spec.ts',
#    'loading-overlay.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\markdown-view-dialog',
#   [],
#   ['markdown-view-dialog.component.html',
#    'markdown-view-dialog.component.scss',
#    'markdown-view-dialog.component.spec.ts',
#    'markdown-view-dialog.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\multiple-choice-dialog',
#   [],
#   ['multiple-choice-dialog.component.html',
#    'multiple-choice-dialog.component.scss',
#    'multiple-choice-dialog.component.spec.ts',
#    'multiple-choice-dialog.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\object-status',
#   [],
#   ['object-status.component.html',
#    'object-status.component.scss',
#    'object-status.component.spec.ts',
#    'object-status.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\resources-drawer',
#   ['history-timeline', 'notes-editor', 'reference-manager'],
#   ['resources-drawer.component.html',
#    'resources-drawer.component.scss',
#    'resources-drawer.component.spec.ts',
#    'resources-drawer.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\resources-drawer\\history-timeline',
#   [],
#   ['history-timeline.component.html',
#    'history-timeline.component.scss',
#    'history-timeline.component.spec.ts',
#    'history-timeline.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\resources-drawer\\notes-editor',
#   [],
#   ['notes-editor.component.html',
#    'notes-editor.component.scss',
#    'notes-editor.component.spec.ts',
#    'notes-editor.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\resources-drawer\\reference-manager',
#   ['reference-edit-dialog'],
#   ['reference-manager.component.html',
#    'reference-manager.component.scss',
#    'reference-manager.component.spec.ts',
#    'reference-manager.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\resources-drawer\\reference-manager\\reference-edit-dialog',
#   [],
#   ['reference-edit-dialog.component.html',
#    'reference-edit-dialog.component.scss',
#    'reference-edit-dialog.component.spec.ts',
#    'reference-edit-dialog.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\save-dialog',
#   [],
#   ['save-dialog.component.html',
#    'save-dialog.component.scss',
#    'save-dialog.component.spec.ts',
#    'save-dialog.component.ts']),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\stix',
#   ['alias-property',
#    'attackid-property',
#    'descriptive-property',
#    'external-references-property',
#    'icon-view',
#    'identity-property',
#    'list-property',
#    'name-property',
#    'ordered-list-property',
#    'stix-list',
#    'timestamp-property',
#    'version-property'],
#   []),
#  ('c:\\attackworkbench\\attack-workbench-frontend\\app\\src\\app\\components\\stix\\alias-property',
#   ['alias-edit', 'alias-view'],
#   ['alias-property.component.html',
#    'alias-property.component.scss',
#    'alias-property.component.spec.ts',
#    'alias-property.component.ts']),
# ...
#    'SingleButtonDropdownsDanger@5to4x.png',
#    'SingleButtonDropdownsDanger_D.png',
#    'SingleButtonDropdownsDanger_D@2x.png',
#    'SingleButtonDropdownsDanger_D@3to2x.png',
#    'SingleButtonDropdownsDanger_D@3x.png',
#    'SingleButtonDropdownsDanger_D@5to4x.png',
#    'SingleButtonDropdownsDark.png',
#    'SingleButtonDropdownsDark@2x.png',
#    'SingleButtonDropdownsDark@3to2x.png',
#    'SingleButtonDropdownsDark@3x.png',
#    'SingleButtonDropdownsDark@5to4x.png',
#    'SingleButtonDropdownsDark_D.png',
#    'SingleButtonDropdownsDark_D@2x.png',
#    'SingleButtonDropdownsDark_D@3to2x.png',
#    'SingleButtonDropdownsDark_D@3x.png',
#    'SingleButtonDropdownsDark_D@5to4x.png',
#    'SingleButtonDropdownsDefault.png',
#    'SingleButtonDropdownsDefault@2x.png',
#    'SingleButtonDropdownsDefault@3to2x.png',
#    'SingleButtonDropdownsDefault@3x.png',
#    'SingleButtonDropdownsDefault@5to4x.png',
#    'SingleButtonDropdownsDefault_D.png',
#    'SingleButtonDropdownsDefault_D@2x.png',
#    'SingleButtonDropdownsDefault_D@3to2x.png',
#    'SingleButtonDropdownsDefault_D@3x.png',
#    'SingleButtonDropdownsDefault_D@5to4x.png',
#    'SingleButtonDropdownsInfo.png',
#    'SingleButtonDropdownsInfo@2x.png',
#    'SingleButtonDropdownsInfo@3to2x.png',
#    'SingleButtonDropdownsInfo@3x.png',
#    'SingleButtonDropdownsInfo@5to4x.png',
#    'SingleButtonDropdownsInfo_D.png',
#    'SingleButtonDropdownsInfo_D@2x.png',
#    'SingleButtonDropdownsInfo_D@3to2x.png',
#    'SingleButtonDropdownsInfo_D@3x.png',
#    'SingleButtonDropdownsInfo_D@5to4x.png',
#    'SingleButtonDropdownsLarge.png',
#    'SingleButtonDropdownsLarge@2x.png',
#    'SingleButtonDropdownsLarge@3to2x.png',
#    'SingleButtonDropdownsLarge@3x.png',
#    'SingleButtonDropdownsLarge@5to4x.png',
#    'SingleButtonDropdownsLarge_D.png',
#    'SingleButtonDropdownsLarge_D@2x.png',
#    'SingleButtonDropdownsLarge_D@3to2x.png',
#    'SingleButtonDropdownsLarge_D@3x.png',
#    'SingleButtonDropdownsLarge_D@5to4x.png',
#    'SingleButtonDropdownsLight.png',
#    'SingleButtonDropdownsLight@2x.png',
#    'SingleButtonDropdownsLight@3to2x.png',
#    'SingleButtonDropdownsLight@3x.png',
#    'SingleButtonDropdownsLight@5to4x.png',
#    'SingleButtonDropdownsLight_D.png',
#    'SingleButtonDropdownsLight_D@2x.png',
#    'SingleButtonDropdownsLight_D@3to2x.png',
#    'SingleButtonDropdownsLight_D@3x.png',
#    'SingleButtonDropdownsLight_D@5to4x.png',
#    'SingleButtonDropdownsLink.png',
#    'SingleButtonDropdownsLink@2x.png',
#    'SingleButtonDropdownsLink@3to2x.png',
#    'SingleButtonDropdownsLink@3x.png',
#    'SingleButtonDropdownsLink@5to4x.png',
#    'SingleButtonDropdownsLink_D.png',
#    'SingleButtonDropdownsLink_D@2x.png',
#    'SingleButtonDropdownsLink_D@3to2x.png',
#    'SingleButtonDropdownsLink_D@3x.png',
#    'SingleButtonDropdownsLink_D@5to4x.png',
#    'SingleButtonDropdownsPrimary.png',
#    'SingleButtonDropdownsPrimary@2x.png',
#    'SingleButtonDropdownsPrimary@3to2x.png',
#    'SingleButtonDropdownsPrimary@3x.png',
#    'SingleButtonDropdownsPrimary@5to4x.png',
#    'SingleButtonDropdownsPrimary_D.png',
#    'SingleButtonDropdownsPrimary_D@2x.png',
#    'SingleButtonDropdownsPrimary_D@3to2x.png',
#    'SingleButtonDropdownsPrimary_D@3x.png',
#    'SingleButtonDropdownsPrimary_D@5to4x.png',
#    'SingleButtonDropdownsSmall.png',
#    'SingleButtonDropdownsSmall@2x.png',
#    'SingleButtonDropdownsSmall@3to2x.png',
#    'SingleButtonDropdownsSmall@3x.png',
#    'SingleButtonDropdownsSmall@5to4x.png',
#    'SingleButtonDropdownsSmall_D.png',
#    'SingleButtonDropdownsSmall_D@2x.png',
#    'SingleButtonDropdownsSmall_D@3to2x.png',
#    'SingleButtonDropdownsSmall_D@3x.png',
#    'SingleButtonDropdownsSmall_D@5to4x.png',
#    'SingleButtonDropdownsSuccess.png',
#    'SingleButtonDropdownsSuccess@2x.png',
#    'SingleButtonDropdownsSuccess@3to2x.png',
#    'SingleButtonDropdownsSuccess@3x.png',
#    'SingleButtonDropdownsSuccess@5to4x.png',
#    'SingleButtonDropdownsSuccess_D.png',
#    'SingleButtonDropdownsSuccess_D@2x.png',
#    'SingleButtonDropdownsSuccess_D@3to2x.png',
#    'SingleButtonDropdownsSuccess_D@3x.png',
#    'SingleButtonDropdownsSuccess_D@5to4x.png',
#    'SingleButtonDropdownsWarning.png',
#    'SingleButtonDropdownsWarning@2x.png',
#    'SingleButtonDropdownsWarning@3to2x.png',
#    'SingleButtonDropdownsWarning@3x.png',
#    'SingleButtonDropdownsWarning@5to4x.png',
#    'SingleButtonDropdownsWarning_D.png',
#    'SingleButtonDropdownsWarning_D@2x.png',
#    'SingleButtonDropdownsWarning_D@3to2x.png',
#    'SingleButtonDropdownsWarning_D@3x.png',
#    'SingleButtonDropdownsWarning_D@5to4x.png']),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Objects\\Responsive\\Spinners',
#   [],
#   ['responsiveSpinnersBorder.htm',
#    'responsiveSpinnersButtonBorder.htm',
#    'responsiveSpinnersButtonGrow.htm',
#    'responsiveSpinnersGrow.htm',
#    'Spinners.png',
#    'Spinners@2x.png',
#    'Spinners@3to2x.png',
#    'Spinners@3x.png',
#    'Spinners@5to4x.png',
#    'SpinnersBorder.png',
#    'SpinnersBorder@2x.png',
#    'SpinnersBorder@3to2x.png',
#    'SpinnersBorder@3x.png',
#    'SpinnersBorder@5to4x.png',
#    'SpinnersBorder_D.png',
#    'SpinnersBorder_D@2x.png',
#    'SpinnersBorder_D@3to2x.png',
#    'SpinnersBorder_D@3x.png',
#    'SpinnersBorder_D@5to4x.png',
#    'SpinnersButtonBorder.png',
#    'SpinnersButtonBorder@2x.png',
#    'SpinnersButtonBorder@3to2x.png',
#    'SpinnersButtonBorder@3x.png',
#    'SpinnersButtonBorder@5to4x.png',
#    'SpinnersButtonBorder_D.png',
#    'SpinnersButtonBorder_D@2x.png',
#    'SpinnersButtonBorder_D@3to2x.png',
#    'SpinnersButtonBorder_D@3x.png',
#    'SpinnersButtonBorder_D@5to4x.png',
#    'SpinnersButtonGrow.png',
#    'SpinnersButtonGrow@2x.png',
#    'SpinnersButtonGrow@3to2x.png',
#    'SpinnersButtonGrow@3x.png',
#    'SpinnersButtonGrow@5to4x.png',
#    'SpinnersButtonGrow_D.png',
#    'SpinnersButtonGrow_D@2x.png',
#    'SpinnersButtonGrow_D@3to2x.png',
#    'SpinnersButtonGrow_D@3x.png',
#    'SpinnersButtonGrow_D@5to4x.png',
#    'SpinnersGrow.png',
#    'SpinnersGrow@2x.png',
#    'SpinnersGrow@3to2x.png',
#    'SpinnersGrow@3x.png',
#    'SpinnersGrow@5to4x.png',
#    'SpinnersGrow_D.png',
#    'SpinnersGrow_D@2x.png',
#    'SpinnersGrow_D@3to2x.png',
#    'SpinnersGrow_D@3x.png',
#    'SpinnersGrow_D@5to4x.png',
#    'Spinners_D.png',
#    'Spinners_D@2x.png',
#    'Spinners_D@3to2x.png',
#    'Spinners_D@3x.png',
#    'Spinners_D@5to4x.png']),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Objects\\Responsive\\SplitButtonDropdowns',
#   [],
#   ['responsiveSplitButtonDropdownsDanger.htm',
#    'responsiveSplitButtonDropdownsDark.htm',
#    'responsiveSplitButtonDropdownsDefault.htm',
#    'responsiveSplitButtonDropdownsInfo.htm',
#    'responsiveSplitButtonDropdownsLarge.htm',
#    'responsiveSplitButtonDropdownsLight.htm',
#    'responsiveSplitButtonDropdownsLink.htm',
#    'responsiveSplitButtonDropdownsPrimary.htm',
#    'responsiveSplitButtonDropdownsSecondary.htm',
#    'responsiveSplitButtonDropdownsSmall.htm',
#    'responsiveSplitButtonDropdownsSuccess.htm',
#    'responsiveSplitButtonDropdownsWarning.htm',
#    'SplitButtonDropdownsDanger.png',
#    'SplitButtonDropdownsDanger@2x.png',
#    'SplitButtonDropdownsDanger@3to2x.png',
#    'SplitButtonDropdownsDanger@3x.png',
#    'SplitButtonDropdownsDanger@5to4x.png',
#    'SplitButtonDropdownsDanger_D.png',
#    'SplitButtonDropdownsDanger_D@2x.png',
#    'SplitButtonDropdownsDanger_D@3to2x.png',
#    'SplitButtonDropdownsDanger_D@3x.png',
#    'SplitButtonDropdownsDanger_D@5to4x.png',
#    'SplitButtonDropdownsDark.png',
#    'SplitButtonDropdownsDark@2x.png',
#    'SplitButtonDropdownsDark@3to2x.png',
#    'SplitButtonDropdownsDark@3x.png',
#    'SplitButtonDropdownsDark@5to4x.png',
#    'SplitButtonDropdownsDark_D.png',
#    'SplitButtonDropdownsDark_D@2x.png',
#    'SplitButtonDropdownsDark_D@3to2x.png',
#    'SplitButtonDropdownsDark_D@3x.png',
#    'SplitButtonDropdownsDark_D@5to4x.png',
#    'SplitButtonDropdownsDefault.png',
#    'SplitButtonDropdownsDefault@2x.png',
#    'SplitButtonDropdownsDefault@3to2x.png',
#    'SplitButtonDropdownsDefault@3x.png',
#    'SplitButtonDropdownsDefault@5to4x.png',
#    'SplitButtonDropdownsDefault_D.png',
#    'SplitButtonDropdownsDefault_D@2x.png',
#    'SplitButtonDropdownsDefault_D@3to2x.png',
#    'SplitButtonDropdownsDefault_D@3x.png',
#    'SplitButtonDropdownsDefault_D@5to4x.png',
#    'SplitButtonDropdownsInfo.png',
#    'SplitButtonDropdownsInfo@2x.png',
#    'SplitButtonDropdownsInfo@3to2x.png',
#    'SplitButtonDropdownsInfo@3x.png',
#    'SplitButtonDropdownsInfo@5to4x.png',
#    'SplitButtonDropdownsInfo_D.png',
#    'SplitButtonDropdownsInfo_D@2x.png',
#    'SplitButtonDropdownsInfo_D@3to2x.png',
#    'SplitButtonDropdownsInfo_D@3x.png',
#    'SplitButtonDropdownsInfo_D@5to4x.png',
#    'SplitButtonDropdownsLarge.png',
#    'SplitButtonDropdownsLarge@2x.png',
#    'SplitButtonDropdownsLarge@3to2x.png',
#    'SplitButtonDropdownsLarge@3x.png',
#    'SplitButtonDropdownsLarge@5to4x.png',
#    'SplitButtonDropdownsLarge_D.png',
#    'SplitButtonDropdownsLarge_D@2x.png',
#    'SplitButtonDropdownsLarge_D@3to2x.png',
#    'SplitButtonDropdownsLarge_D@3x.png',
#    'SplitButtonDropdownsLarge_D@5to4x.png',
#    'SplitButtonDropdownsLight.png',
#    'SplitButtonDropdownsLight@2x.png',
#    'SplitButtonDropdownsLight@3to2x.png',
#    'SplitButtonDropdownsLight@3x.png',
#    'SplitButtonDropdownsLight@5to4x.png',
#    'SplitButtonDropdownsLink.png',
#    'SplitButtonDropdownsLink@2x.png',
#    'SplitButtonDropdownsLink@3to2x.png',
#    'SplitButtonDropdownsLink@3x.png',
#    'SplitButtonDropdownsLink@5to4x.png',
#    'SplitButtonDropdownsLink_D.png',
#    'SplitButtonDropdownsLink_D@2x.png',
#    'SplitButtonDropdownsLink_D@3to2x.png',
#    'SplitButtonDropdownsLink_D@3x.png',
#    'SplitButtonDropdownsLink_D@5to4x.png',
#    'SplitButtonDropdownsPrimary.png',
#    'SplitButtonDropdownsPrimary@2x.png',
#    'SplitButtonDropdownsPrimary@3to2x.png',
#    'SplitButtonDropdownsPrimary@3x.png',
#    'SplitButtonDropdownsPrimary@5to4x.png',
#    'SplitButtonDropdownsPrimary_D.png',
#    'SplitButtonDropdownsPrimary_D@2x.png',
#    'SplitButtonDropdownsPrimary_D@3to2x.png',
#    'SplitButtonDropdownsPrimary_D@3x.png',
#    'SplitButtonDropdownsPrimary_D@5to4x.png',
#    'SplitButtonDropdownsSmall.png',
#    'SplitButtonDropdownsSmall@2x.png',
#    'SplitButtonDropdownsSmall@3to2x.png',
#    'SplitButtonDropdownsSmall@3x.png',
#    'SplitButtonDropdownsSmall@5to4x.png',
#    'SplitButtonDropdownsSmall_D.png',
#    'SplitButtonDropdownsSmall_D@2x.png',
#    'SplitButtonDropdownsSmall_D@3to2x.png',
#    'SplitButtonDropdownsSmall_D@3x.png',
#    'SplitButtonDropdownsSmall_D@5to4x.png',
#    'SplitButtonDropdownsSuccess.png',
#    'SplitButtonDropdownsSuccess@2x.png',
#    'SplitButtonDropdownsSuccess@3to2x.png',
#    'SplitButtonDropdownsSuccess@3x.png',
#    'SplitButtonDropdownsSuccess@5to4x.png',
#    'SplitButtonDropdownsSuccess_D.png',
#    'SplitButtonDropdownsSuccess_D@2x.png',
#    'SplitButtonDropdownsSuccess_D@3to2x.png',
#    'SplitButtonDropdownsSuccess_D@3x.png',
#    'SplitButtonDropdownsSuccess_D@5to4x.png',
#    'SplitButtonDropdownsWarning.png',
#    'SplitButtonDropdownsWarning@2x.png',
#    'SplitButtonDropdownsWarning@3to2x.png',
#    'SplitButtonDropdownsWarning@3x.png',
#    'SplitButtonDropdownsWarning@5to4x.png',
#    'SplitButtonDropdownsWarning_D.png',
#    'SplitButtonDropdownsWarning_D@2x.png',
#    'SplitButtonDropdownsWarning_D@3to2x.png',
#    'SplitButtonDropdownsWarning_D@3x.png',
#    'SplitButtonDropdownsWarning_D@5to4x.png']),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Objects\\Script',
#   [],
#   ['Script.htm',
#    'Script.js',
#    'Script.png',
#    'Script@2x.png',
#    'Script@3to2x.png',
#    'Script@3x.png',
#    'Script@5to4x.png',
#    'Script_D.png',
#    'Script_D@2x.png',
#    'Script_D@3to2x.png',
#    'Script_D@3x.png',
#    'Script_D@5to4x.png']),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Objects\\Tables',
#   [],
#   ['Caption.gif',
#    'Caption.htm',
#    'TableTag.htm',
#    'TableTag.png',
#    'TableTag@2x.png',
#    'Td.gif',
#    'Td.htm',
#    'Th.gif',
#    'Th.htm',
#    'Tr.gif',
#    'Tr.htm']),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Objects\\Templates',
#   [],
#   ['Editable.htm',
#    'Editable.png',
#    'Editable@2x.png',
#    'Editable@3to2x.png',
#    'Editable@3x.png',
#    'Editable@5to4x.png',
#    'Editable_D.png',
#    'Editable_D@2x.png',
#    'Editable_D@3to2x.png',
#    'Editable_D@3x.png',
#    'Editable_D@5to4x.png',
#    'MakeNestedTemplate.htm',
#    'MakeNestedTemplate.png',
#    'MakeNestedTemplate@2x.png',
#    'MakeNestedTemplate@3to2x.png',
#    'MakeNestedTemplate@3x.png',
#    'MakeNestedTemplate@5to4x.png',
#    'MakeNestedTemplate_D.png',
#    'MakeNestedTemplate_D@2x.png',
#    'MakeNestedTemplate_D@3to2x.png',
#    'MakeNestedTemplate_D@3x.png',
#    'MakeNestedTemplate_D@5to4x.png',
#    'MakeTemplate.htm',
#    'MakeTemplate.png',
#    'MakeTemplate@2x.png',
#    'MakeTemplate@3to2x.png',
#    'MakeTemplate@3x.png',
#    'MakeTemplate@5to4x.png',
#    'MakeTemplate_D.png',
#    'MakeTemplate_D@2x.png',
#    'MakeTemplate_D@3to2x.png',
#    'MakeTemplate_D@3x.png',
#    'MakeTemplate_D@5to4x.png',
#    'Optional.htm',
#    'Optional.png',
#    'Optional@2x.png',
#    'Optional@3to2x.png',
#    'Optional@3x.png',
#    'Optional@5to4x.png',
#    'OptionalWithEdit.htm',
#    'OptionalWithEdit.png',
#    'OptionalWithEdit@2x.png',
#    'OptionalWithEdit@3to2x.png',
#    'OptionalWithEdit@3x.png',
#    'OptionalWithEdit@5to4x.png',
#    'OptionalWithEdit_D.png',
#    'OptionalWithEdit_D@2x.png',
#    'OptionalWithEdit_D@3to2x.png',
#    'OptionalWithEdit_D@3x.png',
#    'OptionalWithEdit_D@5to4x.png',
#    'Optional_D.png',
#    'Optional_D@2x.png',
#    'Optional_D@3to2x.png',
#    'Optional_D@3x.png',
#    'Optional_D@5to4x.png',
#    'Repeating.htm',
#    'Repeating.png',
#    'Repeating@2x.png',
#    'Repeating@3to2x.png',
#    'Repeating@3x.png',
#    'Repeating@5to4x.png',
#    'RepeatingTable.htm',
#    'RepeatingTable.png',
#    'RepeatingTable@2x.png',
#    'RepeatingTable@3to2x.png',
#    'RepeatingTable@3x.png',
#    'RepeatingTable@5to4x.png',
#    'RepeatingTable_D.png',
#    'RepeatingTable_D@2x.png',
#    'RepeatingTable_D@3to2x.png',
#    'RepeatingTable_D@3x.png',
#    'RepeatingTable_D@5to4x.png',
#    'Repeating_D.png',
#    'Repeating_D@2x.png',
#    'Repeating_D@3to2x.png',
#    'Repeating_D@3x.png',
#    'Repeating_D@5to4x.png']),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Objects\\Text',
#   [],
#   ['Comment.png',
#    'Comment@2x.png',
#    'FontTagDlg.gif',
#    'LI.htm',
#    'LI.png',
#    'LI@2x.png',
#    'LI@3to2x.png',
#    'LI@3x.png',
#    'LI@5to4x.png',
#    'LI_D.png',
#    'LI_D@2x.png',
#    'LI_D@3to2x.png',
#    'LI_D@3x.png',
#    'LI_D@5to4x.png',
#    'OL.htm',
#    'OL.png',
#    'OL@2x.png',
#    'OL@3to2x.png',
#    'OL@3x.png',
#    'OL@5to4x.png',
#    'OL_D.png',
#    'OL_D@2x.png',
#    'OL_D@3to2x.png',
#    'OL_D@3x.png',
#    'OL_D@5to4x.png',
#    'UL.htm',
#    'UL.png',
#    'UL@2x.png',
#    'UL@3to2x.png',
#    'UL@3x.png',
#    'UL@5to4x.png',
#    'UL_D.png',
#    'UL_D@2x.png',
#    'UL_D@3to2x.png',
#    'UL_D@3x.png',
#    'UL_D@5to4x.png']),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Overlays',
#   ['CssGrids'],
#   []),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Overlays\\CssGrids',
#   ['assets', 'images', 'temp'],
#   ['LayoutDivManipulator.htm', 'shouldDesignViewSnap.txt']),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Overlays\\CssGrids\\assets',
#   [],
#   ['LayoutDivManipulator.css', 'LayoutDivManipulator.js']),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Overlays\\CssGrids\\images',
#   [],
#   ['Align_hover.png',
#    'Align_up.png',
#    'Checks.png',
#    'Delete_hover.png',
#    'Delete_up.png',
#    'Duplicate_hover.png',
#    'Duplicate_up.png',
#    'Hide_hover.png',
#    'Hide_up.png',
#    'knob.png',
#    'Lock_hover.png',
#    'Lock_up.png',
#    'Move_Down_hover.png',
#    'Move_Down_up.png',
#    'Move_Up_hover.png',
#    'Move_Up_Row_hover.png',
#    'Move_Up_Row_up.png',
#    'Move_Up_up.png',
#    'piX.png',
#    'Start_New_Row_hover.png',
#    'Start_New_Row_up.png',
#    'Unlock_hover.png',
#    'Unlock_up.png',
#    'View_hover.png',
#    'View_up.png']),
#  ('c:\\Program Files\\Adobe\\Adobe Dreamweaver 2021\\configuration\\Overlays\\CssGrids\\temp',
#   [],
#   ['internal.css']),
#  ...]

# %% [markdown]
# ___
# Excellent, you should now be aware of how to work with a computer's files and folders in whichever directory they are in. Remember that the os module works for any oeprating system that supports Python, which means these commands will work across Linux,MacOs, or Windows without need for adjustment.
